# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\SDR\Desktop\iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.mean()
# Out:
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
data.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
data.median()
# Out:
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
data.mode()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
data["SepalLengthCm"].mean()
# Out:
# 5.843333333333335

# %%
x=data[["SepalLengthCm","PetalLengthCm"]]
x
# Out:
#      SepalLengthCm  PetalLengthCm
# 0              5.1            1.4
# 1              4.9            1.4
# 2              4.7            1.3
# 3              4.6            1.5
# 4              5.0            1.4
# ..             ...            ...
# 145            6.7            5.2
# 146            6.3            5.0
# 147            6.5            5.2
# 148            6.2            5.4
# 149            5.9            5.1
#
# [150 rows x 2 columns]

# %%
y=data[["Species"]]
y.head()
# Out:
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
data.iloc[0:6,0:]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
data.loc[1:5,("SepalLengthCm","PetalLengthCm")]
# Out:
#    SepalLengthCm  PetalLengthCm
# 1            4.9            1.4
# 2            4.7            1.3
# 3            4.6            1.5
# 4            5.0            1.4
# 5            5.4            1.7

# %%
data[0:4]=np.nan
data
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      NaN            NaN           NaN            NaN           NaN
# 1      NaN            NaN           NaN            NaN           NaN
# 2      NaN            NaN           NaN            NaN           NaN
# 3      NaN            NaN           NaN            NaN           NaN
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4       Iris-setosa
# ...

# %%
data.notnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4     True           True          True           True          True     True
# ..     ...            ...           ...            ...           ...      ...
# 145   True           True          True           True          True     True
# 146   True           True          True           True          True     True
# 147   True           True          True           True          True     True
# 148   True           True          True           True          True     True
# 149   True           True          True           True          True     True
#
# [150 rows x 6 columns]

# %%
data.count()
# Out:
# Id               146
# SepalLengthCm    146
# SepalWidthCm     146
# PetalLengthCm    146
# PetalWidthCm     146
# Species          146
# dtype: int64

# %%
data.dropna()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 4      5.0            5.0           3.6            1.4           0.2
# 5      6.0            5.4           3.9            1.7           0.4
# 6      7.0            4.6           3.4            1.4           0.3
# 7      8.0            5.0           3.4            1.5           0.2
# 8      9.0            4.4           2.9            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# ...

# %%
data.loc[0:4]=np.nan
data
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      NaN            NaN           NaN            NaN           NaN
# 1      NaN            NaN           NaN            NaN           NaN
# 2      NaN            NaN           NaN            NaN           NaN
# 3      NaN            NaN           NaN            NaN           NaN
# 4      NaN            NaN           NaN            NaN           NaN
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...

# %%
data.fillna(data.mean())
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     78.0       5.877241      3.046207           3.84      1.233103
# 1     78.0       5.877241      3.046207           3.84      1.233103
# 2     78.0       5.877241      3.046207           3.84      1.233103
# 3     78.0       5.877241      3.046207           3.84      1.233103
# 4     78.0       5.877241      3.046207           3.84      1.233103
# ..     ...            ...           ...            ...           ...
# 145  146.0       6.700000      3.000000           5.20      2.300000
# 146  147.0       6.300000      2.500000           5.00      1.900000
# 147  148.0       6.500000      3.000000           5.20      2.000000
# 148  149.0       6.200000      3.400000           5.40      2.300000
# 149  150.0       5.900000      3.000000           5.10      1.800000
#
#             Species
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...

# %%
data.replace(3.0,"ss")
# Out:
#         Id  SepalLengthCm SepalWidthCm PetalLengthCm  PetalWidthCm  \
# 0      NaN            NaN          NaN           NaN           NaN
# 1      NaN            NaN          NaN           NaN           NaN
# 2      NaN            NaN          NaN           NaN           NaN
# 3      NaN            NaN          NaN           NaN           NaN
# 4      NaN            NaN          NaN           NaN           NaN
# ..     ...            ...          ...           ...           ...
# 145  146.0            6.7           ss           5.2           2.3
# 146  147.0            6.3          2.5             5           1.9
# 147  148.0            6.5           ss           5.2           2.0
# 148  149.0            6.2          3.4           5.4           2.3
# 149  150.0            5.9           ss           5.1           1.8
#
#             Species
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# ...
